# %%
import pandas as pd
import altair as alt

alt.themes.enable('opaque')
# Out:
# ThemeRegistry.enable('opaque')

# %%
position = 'RB'
week = '1'
PATH = 'data/week' + week + '/' + position + '/'

# %%
df = pd.read_csv(PATH + 'RB.csv')
df.head()
# Out:
#                 Player Team  Games  Attempts  RushingYards  RushingTD  \
# 0        Austin Ekeler  LAC      1        12            58          1
# 1  Christian McCaffrey  CAR      1        19           128          2
# 2        Derrick Henry  TEN      1        19            84          1
# 3         Alvin Kamara   NO      1        13            97          0
# 4       Chris Thompson  WAS      1         3            10          0
#
#    Targets  Receptions  ReceivingYards  ReceivingTD  FantasyPoints  \
# 0        7           6              96            2           36.4
# 1       11          10              81            0           37.9
# 2        2           1              75            1           28.4
# 3        8           7              72            0           20.4
# 4       10           7              68            0           11.3
#
#    FantasyPointsPerGame
# 0                  36.4
# 1                  37.9
# 2                  28.4
# 3                  20.4
# 4                  11.3

# %%
data = df[['Player', 'Team', 'ReceivingYards']]

# %%
# Create sorted list of teams in dataframe
# Data is defined below, above charts
teams = sorted((data['Team'].unique()))
teams[:5]
# Out:
# ['ARI', 'ATL', 'BUF', 'CAR', 'CHI']

# %%
# Create list of all 32 teams
all_teams = ['ARI', 'ATL', 'BAL', 'BUF',
             'CAR', 'CHI', 'CIN', 'CLE',
             'DAL', 'DEN', 'DET', 'GB',
             'HOU', 'IND', 'JAC', 'KC', 
             'LAC', 'LAR', 'MIA', 'MIN', 
             'NE', 'NO', 'NYG', 'NYJ', 
             'OAK', 'PHI', 'PIT', 'SEA',
             'SF', 'TB', 'TEN', 'WAS']

# %%
# Sometimes a team can be missing, find which ones
[team for team in all_teams if team not in teams]
# Out:
# ['BAL']

# %%
# Create list of team colors, comment colors for missing teams
color_codes = [
    '#97233F', #ARI
    '#A71930', #ATL
    #'#241773', #BAL
    '#00338D', #BUF
    '#0085CA', #CAR
    '#C83803', #CHI
    '#FB4F14', #CIN
    '#311D00', #CLE
    '#869397', #DAL
    '#FB4F14', #DEN
    '#0076B6', #DET
    '#203731', #GB
    '#03202F', #HOU
    '#002C5F', #IND
    '#006778', #JAC
    '#E31837', #KC
    '#FFC20E', #LAC
    '#866D4B', #LAR
    '#FC4C02', #MIA
    '#4F2683', #MIN
    '#002244', #NE
    '#D3BC8D', #NO
    '#0B2265', #NYG
    '#125740', #NYJ
    '#000000', #OAK
    '#004C54', #PHI
    '#FFB612', #PIT
    '#69BE28', #SEA
    '#AA0000', #SF
    '#D50A0A', #TB
    '#418FDE', #TEN
    '#773141' #WAS
]

# %% [markdown]
# ## Rushing Attempts

# %%
data = df[['Player', 'Team', 'Attempts']]

# %%
chart = alt.Chart(data).mark_bar().encode(
    alt.Y(
        'Attempts:Q',
        axis = alt.Axis(title = 'Rushing Attempts')
    ),
    alt.X(
        'Player:N',
        sort = alt.EncodingSortField(
            field = 'Attempts',
            op = 'sum',
            order = 'descending'
          ),
        axis = alt.Axis(title = '', labelAngle = -45)
    ),
    color = alt.Color(
        'Team:N',
        scale = alt.Scale(
            domain = teams,
            range = color_codes        
        )
    )
).properties(title = 'Week 1: Rushing Attempts by Running Backs')

# %%
chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart.save(PATH + 'plots/RB_attempts_color.png', scale_factor=3.0)

# %%
chart = alt.Chart(data).mark_bar().encode(
    alt.Y(
        'Attempts:Q',
        axis = alt.Axis(title = 'Rushing Attempts')
    ),
    alt.X(
        'Player:N',
        sort = alt.EncodingSortField(
            field = 'Attempts',
            op = 'sum',
            order = 'descending'
          ),
        axis = alt.Axis(title = '', labelAngle = -45)
    )
).properties(title = 'Week 1: Rushing Attempts by Running Backs')

# %%
chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart.save(PATH + 'plots/RB_attempts_normal.png', scale_factor=3.0)

# %% [markdown]
# ## Fantasy Points

# %%
data = df[['Player', 'Team', 'FantasyPoints']]

# %%
chart = alt.Chart(data).mark_bar().encode(
    alt.Y(
        'FantasyPoints:Q',
        axis = alt.Axis(title = 'Fantasy Points')
    ),
    alt.X(
        'Player:N',
        sort = alt.EncodingSortField(
            field = 'FantasyPoints',
            op = 'sum',
            order = 'descending'
          ),
        axis = alt.Axis(title = '', labelAngle = -45)
    ),
    color = alt.Color(
        'Team:N',
        scale = alt.Scale(
            domain = teams,
            range = color_codes        
        )
    )
).properties(title = 'Week 1: 0.5 PPR Fantasy Points by Running Backs')

# %%
chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart.save(PATH + 'plots/RB_points_color.png', scale_factor=3.0)

# %%
chart = alt.Chart(data).mark_bar().encode(
    alt.Y(
        'FantasyPoints:Q',
        axis = alt.Axis(title = 'Fantasy Points')
    ),
    alt.X(
        'Player:N',
        sort = alt.EncodingSortField(
            field = 'FantasyPoints',
            op = 'sum',
            order = 'descending'
          ),
        axis = alt.Axis(title = '', labelAngle = -45)
    )
).properties(title = 'Week 1: 0.5 PPR Fantasy Points by Running Backs')

# %%
chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart.save(PATH + 'plots/RB_points_plain.png', scale_factor=3.0)

# %% [markdown]
# ## Rushing Yards

# %%
data = df[['Player', 'Team', 'RushingYards']]
data = data.loc[data['RushingYards'] >= 20]

# %%
chart = alt.Chart(data).mark_bar().encode(
    alt.Y(
        'RushingYards:Q',
        axis = alt.Axis(title = 'Rushing Yards')
    ),
    alt.X(
        'Player:N',
        sort = alt.EncodingSortField(
            field = 'RushingYards',
            op = 'sum',
            order = 'descending'
          ),
        axis = alt.Axis(title = '', labelAngle = -45)
    ),
    color = alt.Color(
        'Team:N',
        scale = alt.Scale(
            domain = teams,
            range = color_codes        
        )
    )
).properties(title = 'Week 1: Rushing Yards by Running Backs (Minimum 20 yards)')

# %%
chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart.save(PATH + 'plots/RB_rushingyards_color.png', scale_factor=3.0)

# %%
chart = alt.Chart(data).mark_bar().encode(
    alt.Y(
        'RushingYards:Q',
        axis = alt.Axis(title = 'Rushing Yards')
    ),
    alt.X(
        'Player:N',
        sort = alt.EncodingSortField(
            field = 'RushingYards',
            op = 'sum',
            order = 'descending'
          ),
        axis = alt.Axis(title = '', labelAngle = -45)
    )
).properties(title = 'Week 1: Rushing Yards by Running Backs (Minimum 20 yards)')

# %%
chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart.save(PATH + 'plots/RB_rushingyards_plain.png', scale_factor=3.0)

# %% [markdown]
# ## Receiving Yards

# %%
data = df[['Player', 'Team', 'ReceivingYards']]

# %%
chart = alt.Chart(data).mark_bar().encode(
    alt.Y(
        'ReceivingYards:Q',
        axis = alt.Axis(title = 'Receiving Yards')
    ),
    alt.X(
        'Player:N',
        sort = alt.EncodingSortField(
            field = 'ReceivingYards',
            op = 'sum',
            order = 'descending'
          ),
        axis = alt.Axis(title = '', labelAngle = -45)
    ),
    color = alt.Color(
        'Team:N',
        scale = alt.Scale(
            domain = teams,
            range = color_codes        
        )
    )
).properties(title = 'Week 1: Receiving Yards by Running Backs')

# %%
chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart.save(PATH + 'plots/RB_receivingyards_color.png', scale_factor=3.0)

# %%
chart = alt.Chart(data).mark_bar().encode(
    alt.Y(
        'ReceivingYards:Q',
        axis = alt.Axis(title = 'Receiving Yards')
    ),
    alt.X(
        'Player:N',
        sort = alt.EncodingSortField(
            field = 'ReceivingYards',
            op = 'sum',
            order = 'descending'
          ),
        axis = alt.Axis(title = '', labelAngle = -45)
    )
).properties(title = 'Week 1: Receiving Yards by Running Backs')

# %%
chart
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
chart.save(PATH + 'plots/RB_receivingyards_color.png', scale_factor=3.0)
